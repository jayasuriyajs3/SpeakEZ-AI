# %% [markdown]
# ## Confidence score model (trainable)
#
# This notebook demonstrates training a simple ML model (Logistic Regression / RandomForest) that predicts a confidence bucket (`poor|average|good`) from features:
# - filler density
# - WPM
# - continuity
# - eye contact
# - posture
# - voice variation
#
# ### Data
# Fill `training/student_samples/template.csv` with 10–20+ labeled samples.

# %%
import pandas as pd

df = pd.read_csv("../student_samples/template.csv")
df
