# %% [markdown]
# ## Emotion model training (FER2013 → SPEAKEZ labels)
#
# This notebook demonstrates **fine-tuning/validation** for realtime emotion classification.
#
# ### Goals
# - Train a lightweight CNN (or transfer-learning model) to classify:
#   - `happy`, `neutral`, `nervous`, `stressed`
# - Export weights + a `model_card.json` for `backend/models/`.
#
# ### Dataset
# Place the dataset at `training/datasets/fer2013/fer2013.csv`.

# %%
import pandas as pd
import numpy as np

# Load FER2013 CSV
path = "../datasets/fer2013/fer2013.csv"
df = pd.read_csv(path)
df.head()
